# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import torch
import fasttext
import fasttext.util
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk, scan
from elasticsearch_dsl import Search
from elasticsearch_dsl import Q
import operator
import json
import requests
import collections

# %% [markdown]
# ### __READ DATA__

# %%
marketsales_df = pd.read_csv('/Users/onursahil/Documents/Developer/semantic_search_engine/logstash/MarketSales.csv')
marketsales_df = marketsales_df[marketsales_df['ITEMNAME'].notna()]
item_count = dict(collections.Counter(marketsales_df["ITEMNAME"].tolist()))
sorted_item_count = {k: v for k, v in sorted(item_count.items(), key=operator.itemgetter(1), reverse=True)}
del marketsales_df['Unnamed: 0']
marketsales_df.head()
# Out:
# /opt/anaconda3/envs/dev_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         ID  ITEMCODE                         ITEMNAME  FICHENO  \
# 0  11738.0    5863.0  SPRITE 1 LT LIMON AROMALI GAZOZ    18456
# 1  10537.0       8.0                        TOZ SEKER    18105
# 2  11335.0    5979.0             FALIM SAKIZ 5LI NANE    18350
# 3  11336.0    5979.0             FALIM SAKIZ 5LI NANE    18350
# 4  10115.0   12808.0            FALIM SAKIZ 5LI CILEK    18005
#
#                  DATE_  AMOUNT  PRICE  LINENETTOTAL  LINENET  BRANCHNR  ...  \
# 0  2017-01-07 00:00:00     1.0   2.00          2.00     1.85      52.0  ...
# 1  2017-01-06 00:00:00     5.0   2.65         13.25    12.27       8.0  ...
# 2  2017-01-03 00:00:00     1.0   0.40          0.40     0.37      40.0  ...
# 3  2017-01-03 00:00:00     1.0   0.40          0.40     0.37      40.0  ...
# 4  2017-01-05 00:00:00     1.0   0.40          0.40     0.37      41.0  ...
#
#   CLIENTCODE      CLIENTNAME BRANDCODE   BRAND  CATEGORY_NAME1  \
# 0     467369  Sercan KIZILOK       156  SPRİTE          İÇECEK
# 1     131464    İsmet ŞINGIR       NaN     NaN          İÇECEK
# 2     656969     Yağız KUBAL       300   FALIM            GIDA
# 3     656969     Yağız KUBAL       300   FALIM            GIDA
# 4     447336    Habibe AYSAN       300   FALIM            GIDA
#
#     CATEGORY_NAME2      CATEGORY_NAME3            STARTDATE  \
# 0     GAZLI İÇECEK               GAZOZ  2017-01-08 16:16:11
# 1        ÇAY KAHVE  SEKER TATLANDIRICI  2017-01-07 11:04:34
# 2  SAKIZ SEKERLEME               SAKIZ  2017-01-04 14:00:03
# 3  SAKIZ SEKERLEME               SAKIZ  2017-01-04 14:00:03
# 4  SAKIZ SEKERLEME               SAKIZ  2017-01-06 14:00:30
#
#                ENDDATE GENDER
# 0  2017-01-08 16:17:13      E
# 1  2017-01-07 11:05:37      E
# 2  2017-01-04 14:01:01      E
# 3  2017-01-04 14:01:01      E
# 4  2017-01-06 14:01:03      K
#
# [5 rows x 26 columns]

# %%
freq_table = marketsales_df.pivot_table(columns='ITEMNAME', aggfunc='size', fill_value=0).sort_values().to_frame()
freq_table.columns = ['count']
freq_table = freq_table.reset_index()
freq_table[2000:3000]
# Out:
#                                               ITEMNAME  count
# 2000                    POPIFIKS STANDART HASTABEZI 11      3
# 2001                       EQUAL ERKEK DEO SPREY 150ML      3
# 2002             WELLA TUP SAC BOYASI 4,6 KIZIL VIYOLE      3
# 2003                        AXE 250 ML AFRICA DUS JELI      3
# 2004        WELLA PRO-SERIES KOPUK 250ML MAXIMUM GUCLU      3
# ...                                                ...    ...
# 2995  ELIDOR 700ML SAMP.+200 ML SAC KREMI NEMLENDIRICI      5
# 2996               ELIDOR S.KREMI 700 ML RENK KORUYUCU      5
# 2997                                BAGDAT KISNIS 40GR      5
# 2998      LIPTON PIRAMIT YESİL CAY 20LI NANE FERAHLIGI      5
# 2999                   ELSEVE 360ML.SAC KREMI ARI SÜTÜ      5
#
# [1000 rows x 2 columns]

# %%
marketsales_df.ITEMNAME.unique()
# Out:
# array(['SPRITE 1 LT LIMON AROMALI GAZOZ', 'TOZ SEKER',
#        'FALIM SAKIZ 5LI NANE', ..., 'ORAL-B D.F.COCUK STAGES 3',
#        'WEE BABY FIRCA SETI', 'YAREN ARTCRAFT ZEN CAY TAKIMI RENKLI'],
#       dtype=object)

# %% [markdown]
# ### __VECTOR EMBEDDINGS__

# %% [markdown]
# #### Fasttext Turkish sentence vector embedding example

# %%
# Load the fasttext model
ft = fasttext.load_model('cc.tr.300.bin')
ft
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Example sentence vector embedding
example_embedding = ft.get_sentence_vector('sprite 1 lt limon aromali gazoz')
print("Length of the vector: ", len(example_embedding))
list(example_embedding[:5])
# Out:
# Length of the vector:  300
# [-0.005404768, 0.044188257, -0.0042387573, 0.07476722, 0.008084468]

# %% [markdown]
# #### Get unique items
#
# #### Lower case all text
#
# #### Remove newline characters from text
#
# #### Create sentence vector and stack them in a list

# %%
market_items = list(marketsales_df.ITEMNAME.unique())
market_items = [item.lower() for item in market_items]
item_vector = []
for i in range(len(market_items)):
    if "\n" in market_items[i]:
        market_items[i] = market_items[i].replace("\n", " ")
    vector = ft.get_sentence_vector(market_items[i])
    item_vector.append(list(vector))

# %% [markdown]
# ### __ELASTICSEARCH BULK INDEXING SENTENCE VECTORS__

# %%
es = Elasticsearch(['http://localhost:9200'], http_auth=('elastic', 'changeme'))

es_index = {
    "mappings": {
      "properties": {
        "message_text": {
          "type": "text"
        },
        "message_vector": {
          "type": "dense_vector",
          "dims": 300
        }
      }
    }
}

es.indices.create(index='marketsales_vectors', body=es_index, ignore=[400])

def getQuotes():
    for i in range(len(market_items)):
        yield {
            "_index": 'marketsales_vectors',
            "message_text" : market_items[i],
            "message_vector" : item_vector[i]
         }
bulk(client=es, actions = getQuotes(), request_timeout = 120)
# Out:
# (9303, [])

# %% [markdown]
# ### __ELASTICSEARCH SEMANTIC QUERY SEARCH USING COSINE SIMILARITY__

# %%
input_query = "sallama cay"
query_embedding = list(ft.get_sentence_vector(input_query))

script_query = {
        "script_score": {
            "query": {
                "match_all": {}
            },
            "script": {
                "source": "cosineSimilarity(params.query_vector, 'message_vector') + 1.0",
                "params": {
                    "query_vector": query_embedding
                }
            }
        }
    }



client = Elasticsearch(hosts=["localhost"], http_auth=('elastic', 'changeme'))

response = client.search(
    index='marketsales_vectors',
    body={
        "query": script_query
    },
    size=999
)

all_hits = response['hits']['hits']
# all_hits
for i in range(len(all_hits[:10])):
    score = all_hits[i]['_score']
    result_text = all_hits[i]['_source']
    result_text = result_text['message_text']
    vector_list = all_hits[i]['_source']
    vector_list = vector_list['message_vector']
    print("Text: " + result_text + "\n" + "Score: " + str(score) + "\n" + "Vector list: " + str(vector_list[:10]) + "\n\n")
# Out:
# Text: lipton demlik kusburnu poset cay
# Score: 1.7417022
# Vector list: [-0.0311567485332489, 0.02950895205140114, -0.02347765862941742, 0.04442063719034195, 0.015275533311069012, -0.041355155408382416, 0.03210773691534996, -0.011130946688354015, -0.00044403152423910797, 0.025470400229096413]
#
#
# Text: dogus karadeni̇z demlik poset cay 160 ad
# Score: 1.6929257
# Vector list: [-0.03983846306800842, 0.022559067234396935, -0.03428309038281441, 0.008995119482278824, 0.0007876456365920603, -0.0182204470038414, 0.007209262810647488, -0.030768129974603653, -0.025193659588694572, -0.005843133199959993]
#
#
# Text: dogadan yesil cay balli 20 suzen cay
# Score: 1.692445
# Vector list: [-0.07033774256706238, 0.03250548988580704, -0.014419568702578545, 0.03177532181143761, 0.025982819497585297, -0.014540744945406914, -0.013237175531685352, -0.028703510761260986, 0.005484489258378744, 0.009685290046036243]
#
#
# Text: lipton piramit yesi̇l cay 20li nane ferahligi
# Score: 1.6818882
# Vector list: [-0.030682513490319252, 0.017330750823020935, -0.026841208338737488, 0.031148308888077736, 0.01629379205405712, -0.016971392557024956, 0.014418058097362518, -0.006788118276745081, 0.018147850409150124, 0.014588873833417892]
#
#
# Text: lipton piramit yesi̇l cay 20li
# Score: 1.6741877
# Vector list: [-0.060859303921461105, 0.002787551376968622, -0.02885548584163189, 0.032302264124155045, 0.025852566584944725, -0.011906507425010204, 0.043692007660865784, -0.010408452711999416, 0.017882442101836205, 0.0020714791025966406]
#
#
# Text: dogus karadeniz cay demlik 100'lu bergamotlu
# Score: 1.6726182
# Vector list: [-0.032955020666122437, 0.05262109264731407, -0.013268081471323967, 1.2679646715696435e-05, 0.030935846269130707, 0.0038390164263546467, 0.009404828771948814, -0.037922654300928116, 0.008204394951462746, -0.001300095347687602]
#
#
# Text: dogadan earl grey 48li demlik poset cay
# Score: 1.6692244
# Vector list: [-0.06950493901968002, 0.01381042692810297, 0.001741525949910283, 0.039121441543102264, 0.01506604254245758, -0.028875473886728287, 0.009589139372110367, -0.0034530467819422483, -0.001811425550840795, -0.012923194095492363]
#
#
# Text: dogus ihlamur 20li poset cay
# Score: 1.662392
# Vector list: [-0.0378798246383667, 0.02048986218869686, -0.027473395690321922, 0.02734166756272316, 0.018965989351272583, -0.017610730603337288, -0.005101238377392292, 0.010233140550553799, 0.026718517765402794, -0.014569244347512722]
#
#
# Text: dogus karadeniz cay demlik 48'li bergamotlu
# Score: 1.6613752
# Vector list: [-0.036066602915525436, 0.045859139412641525, -0.023802850395441055, 0.012691214680671692, 0.009040260687470436, -0.011135799810290337, 0.011051992885768414, -0.04858072102069855, 0.009452173486351967, 0.004264231771230698]
#
#
# Text: dogus filiz cay 1 kg +tomurcuk cay
# Score: 1.6600709
# Vector list: [-0.04142288863658905, 0.04529212415218353, 0.0019509936682879925, 0.013384266756474972, 0.025108035653829575, -0.013574434444308281, -0.0007704503368586302, -0.008170328103005886, 0.004945332184433937, -0.032058484852313995]

# %% [markdown]
# ### __ELASTICSEARCH BM25 QUERY SEARCH__

# %%
client = Elasticsearch(hosts=["localhost"], http_auth=('elastic', 'changeme'))
results = client.search(
        index='marketsales',
        body={
          "query": {
            "multi_match" : {
              "query" : "sallama cay",
              "type": "best_fields",
              "fields" : ["FICHENO"] 
            }
          }
        },
        size=999
    )

result_hits = results['hits']['hits']
score = result_hits[0]['_score']
pos = str(score).find(".")
score_first = int(str(score)[:pos])
for i in range(len(result_hits[800:900])):
    score = result_hits[i]['_score']
    result_text = result_hits[i]['_source']
    result_text = result_text['FICHENO']
    print("Text: " + result_text + "\n" + "Score: " + str(score / score_first) + "\n")
# Out:
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGADAN YESIL CAY BALLI 20 SUZEN CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGUS FILIZ CAY 1 KG +TOMURCUK CAY
# Score: 1.01638488
#
# Text: DOGADAN YESIL CAY BALLI 20 SUZEN CAY
# Score: 1.01638488
#
# Text: CAYKUR FILIZ CAY 1KG
# Score: 0.89528608
#
# Text: P.BAHCE 95290 CAY TAKIMI
# Score: 0.89528608
#
# Text: CAYKUR KAMELYA CAY 500GR
# Score: 0.89528608
#
# Text: CAYKUR KAMELYA CAY 500GR
# Score: 0.89528608
#
# Text: ARTCRAFT CAY BARDAGIM OPTIKLI
# Score: 0.89528608
#
# Text: ULKER DANKEK CAY SAATI
# Score: 0.89528608
#
# Text: CAYKUR KAMELYA CAY 500GR
# Score: 0.89528608
#
# Text: ULKER DANKEK CAY SAATI
# Score: 0.89528608
#
# Text: DOGADAN FORM LIMONLU CAY
# Score: 0.89528608
#
# Text: CAYKUR FILIZ CAY 1KG
# Score: 0.89528608
#
# Text: CAYKUR KAMELYA CAY 1KG
# Score: 0.89528608
#
# Text: CAYKUR FILIZ CAY 1KG
# Score: 0.89528608
#
# Text: CAYKUR KAMELYA CAY 500GR
# Score: 0.89528608
#
# Text: CAYKUR KAMELYA CAY 1KG
# Score: 0.89528608
#
# Text: CAYKUR FILIZ CAY 1KG
# Score: 0.89528608
#
# Text: CAYKUR KAMELYA CAY 500GR
# Score: 0.89528608
#
# Text: ARGEM METAL CAY SUZGECI
# Score: 0.89528608
#
# Text: DOGUS FILIZ CAY 1KG
# Score: 0.89528608
#
# Text: CAYKUR KAMELYA CAY 1KG
# Score: 0.89528608

# %%
client = Elasticsearch(['http://localhost:9200'], http_auth=('elastic', 'changeme'))
search = Search(index='marketsales', using=client)
q = Q("multi_match", query='isirgan otu', fields=["FICHENO"])
s = search.query(q)
results_df = pd.DataFrame((d.to_dict() for d in s.scan()))
# results_df = results_df.drop_duplicates(subset='FICHENO')
results_df
# Out:
#      UNENETTOTAL              ENDDATE LONGITUDE STARTDATE CATEGORY_NAME2  \
# 0            1.0  2017-01-20 18:15:57   37.8667      None    MEYVE SEBZE
# 1            1.0  2017-01-06 15:24:10   38.4189      None    MEYVE SEBZE
# 2            1.0  2017-01-20 18:51:30   41.0053      None    MEYVE SEBZE
# 3            1.0  2017-01-20 17:06:58   37.1591      None    MEYVE SEBZE
# 4            1.0  2017-01-20 16:21:36   39.0626      None    MEYVE SEBZE
# ...          ...                  ...       ...       ...            ...
# 1321         1.0  2017-03-31 18:30:43   37.7765      None    MEYVE SEBZE
# 1322         1.0  2017-03-31 11:18:31   39.7767      None    MEYVE SEBZE
# 1323         1.0  2017-03-31 11:21:13   41.4564      None    MEYVE SEBZE
# 1324         1.0  2017-03-31 15:45:20     40.65      None    MEYVE SEBZE
# 1325         1.0  2017-03-21 15:39:30   40.9128      None    MEYVE SEBZE
#
#      BRAND   DATE_ PRICE           LATITUDE BRANCH  ...          SALESMAN  \
# 0      A25   38481   1.0         İç Anadolu   53.0  ...      Konya Subesi
# 1      A25   17192   1.0                Ege   41.0  ...      İzmir Subesi
# 2      A25   38762   1.0            Marmara   40.0  ...   İstanbul Subesi
# 3      A25   38733   2.0  Güneydoğu Anadolu   71.0  ...  Şanlıurfa Subesi
# 4      A25   38722   1.0       Doğu Anadolu   17.0  ...     Bingöl Subesi
# ...    ...     ...   ...                ...    ...  ...               ...
# 1321   A25  155048   1.0                Ege   25.0  ...    Denizli Subesi
# 1322   A25  155363   1.0         İç Anadolu   32.0  ...  Eskişehir Subesi
# 1323   A25  155364   1.0          Karadeniz   81.0  ...  Zonguldak Subesi
# 1324   A25  155423   1.0            Marmara   79.0  ...     Yalova Subesi
# 1325   A25  138479   1.0          Karadeniz   34.0  ...    Giresun Subesi
#
#          REGION  ITEMCODE          host   FICHENO BRANCHNR column27 ITEMNAME  \
# 0         Konya   96955.0  bc774aa9699f  DERE OTU     0.93        K   5493.0
# 1         İzmir    6294.0  bc774aa9699f  DERE OTU     0.93        K   5493.0
# 2      İstanbul   98699.0  bc774aa9699f  DERE OTU     0.93        K   5493.0
# 3     Şanlıurfa   98413.0  bc774aa9699f  DERE OTU     1.85        K   5493.0
# 4        Bingöl   98354.0  bc774aa9699f  DERE OTU     0.93        K   5493.0
# ...         ...       ...           ...       ...      ...      ...      ...
# 1321    Denizli  598934.0  bc774aa9699f  DERE OTU     0.93        E   5493.0
# 1322  Eskişehir  599878.0  bc774aa9699f  DERE OTU     0.93        K   5493.0
# 1323  Zonguldak  599886.0  bc774aa9699f  DERE OTU     0.93        E   5493.0
# 1324     Yalova  600095.0  bc774aa9699f  DERE OTU     0.93        E   5493.0
# 1325    Giresun  527620.0  bc774aa9699f  DERE OTU     0.93        E   5493.0
#
#      CLIENTCODE             column26
# 0       32.4833  2017-01-20 18:19:20
# 1       27.1287  2017-01-06 15:24:44
# 2        28.977  2017-01-20 18:53:15
# 3       38.7969  2017-01-20 17:08:17
# 4       40.7696  2017-01-20 16:22:18
# ...         ...                  ...
# 1321    29.0864  2017-03-31 18:31:10
# 1322    30.5206  2017-03-31 11:19:02
# 1323    31.7987  2017-03-31 11:21:38
# 1324    29.2667  2017-03-31 15:46:15
# 1325    38.3895  2017-03-21 15:40:25
#
# [1326 rows x 32 columns]

# %%
results_df.columns
# Out:
# Index(['UNENETTOTAL', 'ENDDATE', 'LONGITUDE', 'STARTDATE', 'CATEGORY_NAME2',
#        'BRAND', 'DATE_', 'PRICE', 'LATITUDE', 'BRANCH', 'CATEGORY_NAME3',
#        'path', 'UNENET', 'CATEGORY_NAME1', 'AMOUNT', 'BRANDCODE', 'CLIENTNAME',
#        'message', 'ID', '@timestamp', 'CITY', '@version', 'SALESMAN', 'REGION',
#        'ITEMCODE', 'host', 'FICHENO', 'BRANCHNR', 'column27', 'ITEMNAME',
#        'CLIENTCODE', 'column26'],
#       dtype='object')

# %% [markdown]
# #### __ELASTICSEARCH BASIC / ADVANCED QUERY TYPES__

# %%
# Basic Query - Limited Amount of Result
query_body = {
    "query": {
        "bool": {
            "must": {
                "match": {      
                    "FICHENO": "sakiz"
                }
            }
        }
    }
}
elastic_client = Elasticsearch(hosts=["localhost"], http_auth=('elastic', 'changeme'), size='999')
result = elastic_client.search(index="marketsales", body=query_body)
all_hits = result['hits']['hits']
print(all_hits)

# %%
# Advanced Query - Unlimited Amount of Result - Multi_Match + Multi_Field Result
client = Elasticsearch(['http://localhost:9200'], http_auth=('elastic', 'changeme'))
search = Search(index='marketsales', using=client)
q = Q("multi_match", query='baharat', fields=["FICHENO"])
s = search.query(q)
results_df = pd.DataFrame((d.to_dict() for d in s.scan()))
results_df

# %% [markdown]
# #### Bert-Base-Turkish-Cased Model Sentence Vector Embedding

# %%
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased")
model = AutoModel.from_pretrained("dbmdz/bert-base-turkish-cased")

item_vector_bert = []
for item in market_items:
    inputs = tokenizer(item, return_tensors="pt")
    outputs = model(**inputs)
    last_hidden_states = outputs[0].tolist()
    vector = last_hidden_states[0][0]
    item_vector_bert.append(vector)

# %%
es = Elasticsearch(['http://localhost:9200'], http_auth=('elastic', 'changeme'))

es_index = {
    "mappings": {
      "properties": {
        "message_text": {
          "type": "text"
        },
        "message_vector": {
          "type": "dense_vector",
          "dims": 768
        }
      }
    }
}

es.indices.create(index='marketsales_vectors_bert', body=es_index, ignore=[400])

def getQuotes():
    for i in range(len(market_items)):
        yield {
            "_index": 'marketsales_vectors_bert',
            "message_text" : market_items[i],
            "message_vector" : item_vector_bert[i]
         }
bulk(client=es, actions = getQuotes(), request_timeout = 120)
# Out:
# (9303, [])

# %%
input_query = "dulasik deterjani"
inputs = tokenizer(input_query, return_tensors="pt")
outputs = model(**inputs)
last_hidden_states = outputs[0].tolist()
vector = last_hidden_states[0][0]

script_query = {
        "script_score": {
            "query": {
                "match_all": {}
            },
            "script": {
                "source": "cosineSimilarity(params.query_vector, 'message_vector') + 1.0",
                "params": {
                    "query_vector": vector
                }
            }
        }
    }

client = Elasticsearch(hosts=["localhost"], http_auth=('elastic', 'changeme'))

response = client.search(
    index='marketsales_vectors_bert',
    body={
        "query": script_query
    }
)

all_hits = response['hits']['hits']
for i in range(len(all_hits)):
    result_text = all_hits[i]['_source']
    result_text = result_text['message_text']
    vector_list = all_hits[i]['_source']
    vector_list = vector_list['message_vector']
    print(result_text, vector_list[:10], "\n")
# Out:
# yedigun 250 ml cam amasya ruzgari [-0.34083807468414307, 1.1891112327575684, 0.22604696452617645, 0.19006207585334778, 2.008951425552368, -0.009400218725204468, -0.523705244064331, 0.5507699847221375, 0.1187591552734375, 0.3300856351852417]
#
# komili islak temizlik havlusu [-0.5299723744392395, 1.0744775533676147, 0.1541150063276291, 0.09172935783863068, 2.4276766777038574, -0.05137056112289429, -0.4042316675186157, 0.5230587720870972, 0.46855705976486206, 0.16884171962738037]
#
# duru sivi sabun 300 ml yaban mersini  [-0.44106411933898926, 1.1739500761032104, 0.2763999104499817, -0.1496976912021637, 2.063589572906494, 0.11687879264354706, -0.5081267356872559, 0.9592832326889038, 0.25482451915740967, 0.055020250380039215]
#
# sera firin torbasi [-0.20961275696754456, 1.0348691940307617, 0.2875964045524597, -0.12037423253059387, 2.3430209159851074, 0.17536422610282898, -0.47047317028045654, 0.6014859080314636, 0.1761721521615982, 0.23161175847053528]
#
# vileda sapli super paspas [-0.35303884744644165, 1.184294581413269, 0.1383974850177765, 0.0019926875829696655, 2.2247824668884277, -0.1954624354839325, -0.5593058466911316, 0.511322557926178, 0.24630044400691986, 0.384416788816452]
#
# f saff sivi sabun 500 ml deniz esintisi [-0.4587620496749878, 1.3519566059112549, 0.06241306662559509, -0.07322531938552856, 1.9646668434143066, 0.15623359382152557, -0.4244820475578308, 0.6517640948295593, 0.13914766907691956, 0.5688756704330444]
#
# seker fasulye [-0.42442142963409424, 1.2223808765411377, 0.12390431761741638, -0.11397556960582733, 2.3261983394622803, 0.3574625849723816, -0.5236179232597351, 0.8746215105056763, 0.11535140872001648, 0.2230842411518097]
#
# calgonit buls.mak.temizleyici sivi 100 ml [-0.49526357650756836, 1.2316303253173828, 0.05105450749397278, 0.05349133908748627, 2.008228063583374, -0.1388060450553894, -0.6045465469360352, 0.7657553553581238, 0.31459492444992065, 0.4323955774307251]
#
# clio sivi bulasik deterjan 1lt limon [-0.582057774066925, 1.3892427682876587, 0.16105715930461884, -0.18449810147285461, 1.9565439224243164, 0.19123168289661407, -0.508937418460846, 0.7256951928138733, 0.2417016476392746, 0.08099948614835739]
#
# detan super elektrolikit cihazi [-0.31495392322540283, 1.1060571670532227, 0.29137909412384033, -0.04471123218536377, 2.230865955352783, 0.2162327766418457, -0.42458945512771606, 0.526966392993927, 0.15599703788757324, 0.46280527114868164]
